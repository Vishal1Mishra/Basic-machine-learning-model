# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0     6.800000         0.037490   48.6034                       2004
# 1    15.600000         0.172597  114.8518                       1997
# 2    12.911575         0.054721  107.8254                       1985
# 3    11.800000         0.098312   81.4618                       1998
# 4    17.850000         0.046600  125.1388                       2004
#
#    Item_Outlet_Sales  Item_Fat_Content_LF  Item_Fat_Content_Low Fat  \
# 0           291.6204                    0                         1
# 1          2163.1842                    0                         1
# 2          2387.5588                    0                         1
# 3           161.1236                    0                         1
# 4          1981.4208                    0                         0
#
#    Item_Fat_Content_Regular  Item_Fat_Content_low fat  Item_Fat_Content_reg  \
# ...

# %%
df_train.shape
# Out:
# (1364, 36)

# %%
train_X = df_train.drop(columns=['Item_Outlet_Sales','Outlet_Establishment_Year'],axis=1)
train_y = df_train['Item_Outlet_Sales']

# %%
train_X.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content_LF  \
# 0     6.800000         0.037490   48.6034                    0
# 1    15.600000         0.172597  114.8518                    0
# 2    12.911575         0.054721  107.8254                    0
# 3    11.800000         0.098312   81.4618                    0
# 4    17.850000         0.046600  125.1388                    0
#
#    Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 0                         1                         0
# 1                         1                         0
# 2                         1                         0
# 3                         1                         0
# 4                         0                         1
#
#    Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Baking Goods  \
# 0                         0                     0                       1
# 1                         0                     0                       0
# ...

# %%
test_X = df_test.drop(columns=['Item_Outlet_Sales','Outlet_Establishment_Year'],axis=1)
test_y = df_test['Item_Outlet_Sales']

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(train_X,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
preds_y = lr.predict(test_X)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(test_y,preds_y)
# Out:
# 1010628.1302445631

# %%
import pickle

# %%
filename = 'finalized_model.sav'
pickle.dump(lr, open(filename, 'wb'))
